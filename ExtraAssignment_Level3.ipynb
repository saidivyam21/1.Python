# %%
for i in range(11):
 if( i==10):
     print("value : ",i, "CORRECT")
# Out:
# value :  10 CORRECT

# %%
password = input("Enter the password: ")
if(password =="HOPE@123"):
     print("Your password is correct")
else:
    print("Your password is Incorrect")
# Out:
# Enter the password:  HOPE@123
# Your password is correct

# %%
age = int(input("Age :"))
if(age <= 17):
    print("Children")
elif( 18 <= age < 60):
    print("Adult / Citizen")
elif(60<= age<80):
    print("Senior Citizen")
else:
    print("Super Senior Citizen")
# Out:
# Age : 45
# Adult / Citizen

# %%
number = int(input("Enter any number : "))
if(number >= 0):
        print("No '",number,"' is positive")
else:
    print("No '",number,"' is Negative")
# Out:
# Enter any number :  5
# No  5  is positive

# %%
number = int(input("Enter a number to check: "))
if(number% 5 == 0):
        print("No '",number,"' is divisible by 5")
else:
    print("No '",number,"' not divisible by 5")
# Out:
# Enter a number to check:  56
# No ' 56 ' not divisible by 5
