# %%
from AssignmentFunctions import multipleFunctions

# %%
multipleFunctions.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multipleFunctions.OddEven()
# Out:
# Enter a Number : 4
# 4 is Even number

# %%
multipleFunctions.Elegible()
# Out:
# Your Gender:  Male
# Your Age: 33
# ELIGIBLE

# %%
multipleFunctions.percentage()
# Out:
# Subject1 : 100
# Subject2 : 100
# Subject3 : 90
# Subject4 : 99
# Subject5 : 100
# Total :  489
# percentage :  97.8

# %%
multipleFunctions.triangle()
# Out:
# Height : 45
# Breath : 45
# Area formula:(Height * Breath)/2
# Area of Triangle:  1012.5
# Height1 : 45
# Height2 : 45
# Breath : 45
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle:   135
